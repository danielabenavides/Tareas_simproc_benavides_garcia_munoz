# %% [markdown]
# <img style="float: left; margin: 30px 15px 15px 15px;" src="https://pngimage.net/wp-content/uploads/2018/06/logo-iteso-png-5.png" width="400" height="500" />
#
#
# ### <font color='navy'> Simulación de procesos financieros.
#
# **Nombres:** Daniela Benavides, Renatta García, Pablo Muñoz.
#
# **Fecha:** 29 de octubre del 2020.
#
# **Expediente** : if71483, .
#
# **Profesor:** Oscar David Jaramillo Zuluaga.
#
# # Tarea 8: Clase 16

# %% [markdown]
# # Ejercicio
# ![image.png](attachment:image.png)

# %%
import numpy as np
import matplotlib.pyplot as plt
from itertools import cycle  
import matplotlib.pyplot as plt
import scipy.stats as st     
import pandas as pd

# %% [markdown]
# ## **Solución propuesta por Daniela Benavides**

# %% [markdown]
# $$\int_{1}^{x}\frac{dx}{x^2}=-\frac{1}{x}|_1^x=-\frac{1}{x}+1$$
#
# Igualamos a u:
# $$-\frac{1}{x}+1=u$$
#
# Despejamos x:
# $$x=\frac{1}{1-u}$$

# %%
f_x = lambda x: 1/x**2 if x>=1 else 0

# %% [markdown]
# #### Montecarlo Crudo

# %%
np.random.seed(95555)
f_x = lambda x:1/(x ** 2) if x>=1 else 0
f_inv = lambda u : 1/(1-u)
N = 10
u=np.random.uniform(0,0.99,N)
mc = f_inv(u).mean()
print('La media con montecarlo crudo es:',mc)
# Out:
# La media con montecarlo crudo es: 5.043775142203085

# %%
# Respuesta Pablo Muñoz
#integro en los parametros
fx =lambda x: 1/x**2
# Fx = 1 - 1/x
# U = 1 - 1/x
f_inv = lambda u: 1/(1-u)

N=100
u=np.random.uniform(0.1,0.9,N)
montc=f_inv(u).mean()
montc
# Out:
# 2.9942522292122713

# %% [markdown]
# #### Muestreo estratificado

# %%
np.random.seed(95555)
r1 = np.random.uniform(0,0.6,3)
r2 = np.random.uniform(0.6,0.9,3)
r3 = np.random.uniform(0.9,1,4)

# valores de cada estrato
r  = [r1,r2,r3] 

# cantidad de estratos
m  = range(len(r))  

w  = [1/2,1,4] #pesos

# evaluamos para obterner xi
xi = list(map(f_inv,r)) 

muestras = [list(map(lambda x: f_inv(x), i)) for i in r]
estrato = [list(map(lambda i, w: i/w, i,w))for i in muestras]
m_est = np.concatenate(estrato).mean()
print("La media con 3 estratos es ", m_est)
# Out:
# La media con 3 estratos es  27.628471581215845

# %%
def estratos(x):
    U2 =np.random.rand(x)
    i =np.arange(0,x)
    estratos = (U2+i)/x
    return estratos

# %%
random = estratos(10)
muestras2 = lmuestras = list(map(lambda x: f_inv(x), random))
np.mean(muestras2)
# Out:
# 3.938342937609722

# %% [markdown]
# ## Respuesta pablo muñoz

# %%
def estrat_espaciado(B):
    U2 = np.random.rand(B)
    i = np.arange(0,B)
    estrat = (U2+i)/B
    return estrat

# %%
np.random.seed(10)

u = estrat_espaciado(N)
f_inv(u).mean()
# Out:
# 6.606470077910542

# %% [markdown]
# #### Números complementarios

# %%
# complementarios del primer vector 
u_c = -u 
complementario = f_inv(u_c).mean() #evaluar los complementarios en la función y calculamos la media
complementarios = (mc+complementario)/2 #aplicamos el promedio de las medias
print("La media con el método de números complementarios es ", complementarios)
# Out:
# La media con el método de números complementarios es  2.835504198250315

# %%
# Respuesta Pablo Muñoz
U = np.random.rand(N)
U2 = 1-U
print("La media con el método de números complementarios es ", (f_inv(U).mean() + f_inv(U2).mean())/2)
# Out:
# La media con el método de números complementarios es  6.197723651248996
